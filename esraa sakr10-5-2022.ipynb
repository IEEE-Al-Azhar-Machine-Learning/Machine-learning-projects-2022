# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/unlabel data')

# %%
data=data.drop(['ID'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
s= MinMaxScaler()
s.fit(data)
data=s.transform(data)

# %%
from sklearn.cluster import KMeans
error=[]
k_range=range(1,30)
for k in k_range:
  km=KMeans(n_clusters=k)
  km.fit(data)
  error.append(km.inertia_)

# %%
from matplotlib import pyplot as plt 
plt.plot(k_range,error)

# %%
from sklearn.cluster import KMeans
km=KMeans(n_clusters=10)
y=km.fit_predict(data)
y
# Out:
# array([2, 0, 9, ..., 9, 7, 9], dtype=int32)

# %%
y=pd.DataFrame(y)

# %%
data=pd.DataFrame(data)

# %%
data['y']=y

# %%
data
# Out:
#         0    1         2         3         4    5    6  y
# 0     0.0  0.0  0.844828  0.666667  0.324781  0.5  1.0  0
# 1     1.0  1.0  0.068966  0.333333  0.420210  0.5  1.0  6
# 2     0.0  0.0  0.534483  0.333333  0.195144  0.0  0.0  4
# 3     0.0  0.0  0.465517  0.333333  0.496223  0.5  0.5  7
# 4     0.0  0.0  0.603448  0.333333  0.413842  0.5  0.5  7
# ...   ...  ...       ...       ...       ...  ...  ... ..
# 1995  1.0  0.0  0.500000  0.333333  0.320595  0.0  0.0  1
# 1996  1.0  1.0  0.155172  0.333333  0.299460  0.5  0.0  3
# 1997  0.0  0.0  0.224138  0.000000  0.184871  0.0  0.0  4
# 1998  1.0  1.0  0.103448  0.333333  0.227162  0.0  0.0  8
# 1999  0.0  0.0  0.120690  0.000000  0.119123  0.0  0.0  4
#
# [2000 rows x 8 columns]
